# %% [markdown]
# <a href="https://colab.research.google.com/github/anakingui/portfolio/blob/main/Analitica_ley_ciencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tratamiento de datos(instala las librerías: )
# ==============================================================================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
ley='/content/ley_de_ciencia.txt'

# %%
c1_df = pd.read_fwf(ley)

# %%
from pathlib import Path
txt = Path(ley).read_text()

# %%
lo_men = txt.lower()

# %%
spliiit =lo_men.splitlines()

# %%
texto_minusculas = lo_men.split()

# %%
import regex as re

# %%
patron = "[\w-]+\p{L}+[\w]"
rs = re.findall(patron, lo_men)

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
from nltk import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
def remove_stopwords(texto_tk):
    return [palabra for palabra in texto_tk if palabra not in stpwrd]

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
new_stopwords = ["nacional", "consejo", "humanidades", "ciencias",'así','ley', 
                 'honorable','asamblea','juan','carlos','romero','hicks',
                 'fracción','turnada','segunda','minuta','lic','andrés','manuel',
                 'lópez','obrador','continuación','constancia','65-ii','denominado',
                 'antecedentes','proceso','conforme','contiene','demás','presentan',
                'encargados','trabajos','procedimiento' ,'remitida','describe',
                 'recepción','turno','contenido','comento','desarrollaron',
                 'hace','descripción','resume','motivos','iii','expresan','razonamientos',
                 'argumentos','sustentan','texto','régimen','presenta','construido',
                 'disposiciones','rectificación','través','fecha','notificó','artículo',
                 'sector','presente','caso','sectores','junta','conformidad', 'principios',
                 'deberán','instrumentos','titular','términos',
                 'aplicables','aplicable', 'federativas','evaluación','debe',
                 'realizar','siguiente','manera','objeto','siguientes','realicen',
                 'generales','jurídicas','asimismo','materia','podrá','interno',
                 'equivalente','además','atención','podrá','mediante','ser',
                 'incluyendo','fines','comisiones','establecer','mecanismos',
                 'correspondan','asuntos','partir','normativa','entidad','locales',
                 'operación','legislación','correspondiente','correspondientes',
                 'ejercicio','cumplimiento','deberá','necesarias','abierto','general',
                 'dirección','sistema','federal','actividades','marco']

# %%
stpwrd = nltk.corpus.stopwords.words('spanish')
stpwrd.extend(new_stopwords)

# %%
txt_clsw = remove_stopwords(rs)

# %%
dic = {}
for palabra in txt_clsw:
    if palabra in dic.keys():
        dic[palabra] = dic[palabra] + 1
    else:
        dic[palabra] = 1

# %%
print(dic)
# Out:
# {'unidas': 11, 'ciencia': 58, 'tecnología': 30, 'estudios': 13, 'legislativos': 6, 'mesa': 6, 'directiva': 6, 'cámara': 9, 'senadores': 4, 'estudio': 5, 'dictamen': 13, 'diputados': 10, 'proyecto': 12, 'decreto': 9, 'expide': 6, 'tecnologías': 159, 'innovación': 237, 'reforman': 6, 'entidades': 88, 'paraestatales': 27, 'planeación': 27, 'presentada': 3, 'poder': 2, 'ejecutivo': 10, 'presidente': 4, 'república': 9, 'dictaminadoras': 3, 'fundamento': 3, 'dispuesto': 7, 'artículos': 4, 'relativos': 6, 'orgánica': 8, 'congreso': 3, 'unidos': 12, 'mexicanos': 12, 'numeral': 2, 'reglamento': 9, 'senado': 7, 'soberanía': 6, 'tenor': 3, 'metodología': 2, 'integrantes': 16, 'análisis': 5, 'iniciativas': 4, 'apartado': 4, 'trámite': 4, 'inicio': 1, 'legislativo': 3, 'contenidos': 6, 'alcances': 3, 'consideraciones': 4, 'normativo': 4, 'transitorio': 3, 'describen': 1, 'naturaleza': 6, 'transitoria': 1, 'sesión': 5, 'celebrada': 2, 'diciembre': 4, 'iniciativa': 3, 'adicionan': 3, 'diversas': 5,
# ...

# %%
len(dic)
# Out:
# 2423

# %%
dic
# Out:
# {'unidas': 11,
#  'ciencia': 58,
#  'tecnología': 30,
#  'estudios': 13,
#  'legislativos': 6,
#  'mesa': 6,
#  'directiva': 6,
#  'cámara': 9,
#  'senadores': 4,
#  'estudio': 5,
#  'dictamen': 13,
#  'diputados': 10,
#  'proyecto': 12,
#  'decreto': 9,
#  'expide': 6,
#  'tecnologías': 159,
#  'innovación': 237,
#  'reforman': 6,
#  'entidades': 88,
#  'paraestatales': 27,
#  'planeación': 27,
#  'presentada': 3,
#  'poder': 2,
#  'ejecutivo': 10,
#  'presidente': 4,
#  'república': 9,
#  'dictaminadoras': 3,
#  'fundamento': 3,
#  'dispuesto': 7,
#  'artículos': 4,
#  'relativos': 6,
#  'orgánica': 8,
#  'congreso': 3,
#  'unidos': 12,
#  'mexicanos': 12,
#  'numeral': 2,
#  'reglamento': 9,
#  'senado': 7,
#  'soberanía': 6,
#  'tenor': 3,
#  'metodología': 2,
#  'integrantes': 16,
#  'análisis': 5,
#  'iniciativas': 4,
#  'apartado': 4,
#  'trámite': 4,
#  'inicio': 1,
#  'legislativo': 3,
#  'contenidos': 6,
#  'alcances': 3,
#  'consideraciones': 4,
#  'normativo': 4,
# ...

# %%
from collections import Counter

# %%
contador = Counter(dic)

# %%
n = 100

# %%
print(contador.most_common()[:-n-1:-1] )
# Out:
# [('apego', 1), ('mencionados', 1), ('sujetarse', 1), ('conservarán', 1), ('compete', 1), ('destinar', 1), ('legislaturas', 1), ('compensados', 1), ('movimientos', 1), ('modificación', 1), ('subsecuentes', 1), ('adicionales', 1), ('autorizarán', 1), ('involucrados', 1), ('ahora', 1), ('cubrirán', 1), ('afectará', 1), ('celebrado', 1), ('llevarán', 1), ('realizarlas', 1), ('facultado', 1), ('transcurrido', 1), ('regulados', 1), ('término', 1), ('inscripción', 1), ('iniciados', 1), ('momento', 1), ('atenderán', 1), ('iniciado', 1), ('tramitación', 1), ('agotado', 1), ('jurídico', 1), ('armonizar', 1), ('controversia', 1), ('suceda', 1), ('nuevas', 1), ('entren', 1), ('continuarán', 1), ('modificadas', 1), ('virtud', 1), ('concordancia', 1), ('cabal', 1), ('derogan', 1), ('publicadas', 1), ('ambas', 1), ('entrará', 1), ('anteproyectos', 1), ('incidan', 1), ('procedan', 1), ('adiciona', 1), ('oponga', 1), ('estructuras', 1), ('hubiere', 1), ('análoga', 1), ('armadas', 1), ('seguro', 1), (
# ...

# %%
print(contador.most_common(70) )
# Out:
# [('innovación', 237), ('tecnologías', 159), ('desarrollo', 147), ('públicos', 143), ('investigación', 133), ('centros', 132), ('público', 104), ('gobierno', 95), ('entidades', 88), ('científica', 88), ('personas', 79), ('pública', 78), ('social', 77), ('tecnológico', 75), ('programas', 74), ('persona', 69), ('humanística', 66), ('información', 65), ('educación', 64), ('públicas', 59), ('ciencia', 58), ('políticas', 58), ('instituciones', 52), ('administración', 52), ('nacionales', 49), ('acceso', 47), ('proyectos', 45), ('conocimiento', 45), ('programa', 45), ('secretaría', 45), ('bases', 40), ('recursos', 40), ('superior', 40), ('derechos', 38), ('país', 38), ('científico', 37), ('política', 36), ('universidades', 36), ('coordinación', 36), ('comunidad', 36), ('articulación', 35), ('privado', 35), ('promover', 34), ('órgano', 34), ('agenda', 33), ('derecho', 32), ('garantizar', 32), ('áreas', 32), ('autoridades', 31), ('interés', 31), ('centro', 31), ('tecnología', 30), ('beneficios
# ...

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
corpus_wc = [palabra for vpalabras in txt_clsw for palabra in vpalabras]

# %%
text_wc = " ".join(palabra for palabra in corpus_wc)

# %%
def nube_palabras(corpus, stopwords, color):
    stopwords = set(stopwords)
    wordcloud = WordCloud(
        background_color=color,
        stopwords=stopwords,
        max_words=70,
        max_font_size=45,
        random_state=1)
   
    wordcloud=wordcloud.generate(str(corpus))

    fig = plt.figure(1, figsize=(15, 15))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
nube_palabras(txt_clsw, stpwrd, "white")
